# %%
# !ollama serve

# !ollama pull llama3.2

# !ollama pull nomic-embed-text

# %%
# !mkdir -p ./marketing-assistant

# %%
# !ls -l

# %%
# !pip install langchain langchain-community ollama
# !pip install langchain-ollama

modelfile_path = "./marketing-assistant/untitled.txt"

# !ollama create marketing-assistant -f {modelfile_path}

from langchain_ollama import OllamaLLM
llm = OllamaLLM(model="marketing-assistant")
answer = llm.invoke("hello")
print(answer)

# %%
question = "make to me a contetn strategy and plan in instagram"
answer = llm.invoke(question)
print(answer)
# Out:
# I'd be happy to help you create a content strategy and plan for Instagram. Here's a comprehensive plan that includes the following elements:
#
# **Content Strategy:**
#
# 1. **Define Your Target Audience:** Identify your ideal customer demographics, interests, and behaviors.
# 2. **Determine Your Content Pillars:** Choose 3-5 core topics that align with your brand values and resonate with your target audience (e.g., product showcases, behind-the-scenes content, user-generated content).
# 3. **Develop a Unique Voice:** Create a consistent tone and language that reflects your brand's personality.
# 4. **Content Types:** Mix up the types of content to keep your audience engaged:
# 	* Educational/Informative
# 	* Inspirational/Motivational
# 	* Entertaining/Humorous
# 	* Promotional/Sales-driven
# 5. **Visual Identity:** Establish a consistent visual aesthetic using high-quality images and videos.
#
# **Content Plan:**
#
# ...
